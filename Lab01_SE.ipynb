# %% [markdown]
# #INTRODUCTION

# %% [markdown]
# #### Information Retrieval
#
# Information Retrieval (IR) is finding material (usually **documents**) of an unstructured nature (usually **text**) that satisfies an information need from within large collections (usually stored on computers).

# %% [markdown]
# #### IR is an Empirical Science
#
# * Information Retrieval has massively benefitted from a long history of excellent test collections;
#
# * This has allowed many retrieval models to be developed and shown their effectiveness;
#
# * Hence, IR has been a dataset-driven empirical science for 50 years!

# %% [markdown]
# ##PyTerrier
#
# PyTerrier is a software framework for information retrieval experiements in Python.
#
# *   It embeds all the previous frameworks;
# *   It allows performing experiments in a **declarative way**.

# %% [markdown]
# #### Installing & Configuring
# Installing PyTerrier is easy - it can be installed from the command-line in the normal way using Pip: `pip install python-terrier`

# %% [markdown]
# All usages of PyTerrier start by importing PyTerrier and starting it using the init() method:
#
# ```
# import pyterrier as pt
# pt.init()
# ```

# %% [markdown]
# #### Importing Datasets
# The datasets module allows easy access to existing standard test collections. In particular, each defined dataset can download and provide easy access to:
# * files containing the documents of the corpus
# * topics (queries), as a dataframe, ready for retrieval
# * relevance assessments (aka, labels or qrels), as a dataframe, ready for evaluation
# * ready-made Terrier indices, where appropriate

# %% [markdown]
# #### Indexing
# PyTerrier has a number of useful classes for creating Terrier indices, which can be used for retrieval, query expansion, etc. There are four indexer classes:
#
# * You can create an index from TREC-formatted files, from a TREC test collection, using `TRECCollectionIndexer`.
# * You can use `FilesIndexer` for indexing TXT, PDF, Microsoft Word files, etc.
# * For indexing Pandas Dataframe you can use `DFIndexer`.
# * For any **abitrary iterable dictionaries**, you can use `IterDictIndexer`.

# %% [markdown]
# #### Terrier Retrieval
# **BatchRetrieve** is one of the most commonly used PyTerrier objects. It represents a retrieval transformation, in which queries are mapped to retrieved documents. BatchRetrieve uses a pre-existing Terrier index data structure, typically saved on disk.

# %% [markdown]
# #CODE

# %% [markdown]
# ## Libraries

# %% [markdown]
# > We need to install **PyTerrier** as it is not part of Python standard libraries

# %%
pip install python-terrier
# pip install pyterrier

# %% [markdown]
# > Now we can import **PyTerrier**

# %%
import pyterrier as pt

# %% [markdown]
# > We also need to import the **pandas** library to handle DataFrames

# %%
import pandas as pd

# %% [markdown]
# ### Initialization
# > It is necessary to call the PyTerrier `init` function before Terrier classes and methods can be used. This function imports classes and also finds the correct version of Terrier to download if no version is specified.
#
# > This is a peculiarity of PyTerrier and is not necessary for the other libraries we need.

# %%
if not pt.started():
  pt.init()
# Out:
# terrier-assemblies 5.7 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.7 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7

# %% [markdown]
# > The `started` method of the PyTerrier package returns *True* if `init()` has already been called, `False` otherwise.

# %% [markdown]
# ###Custom functions
# Here are hidden imports and custom functions defined to simplify certain steps or improve certain visual outputs.

# %%
from IPython.display import display, display_html

# %%
def format_query_result(results, df, field):
  merged_df = pd.merge(results, df, left_on='docno', right_on='docno') #merge the two dfs

  merged_df = merged_df.loc[:, ["rank", "score", *field]] #subset to columns we are interested in
  
  return merged_df

# %%
def display_query_result(results_dict, df):
  for field,results in results_dict.items():
    previous_max_col_width = pd.options.display.max_colwidth #save current max_col_width
    pd.options.display.max_colwidth = 1000 #change max_colwidth to display more text
    
    merged_df = format_query_result(results,df,field) #get formatted results
    
    display(merged_df) #display result

    pd.options.display.max_colwidth = previous_max_col_width #reset previous max_col_width

# %%
def display_matrix_results(results_dict):
  df_stylers = []
  for i,(k,v) in enumerate(results_dict.items()):
    if k[0]=="":
      app = "No preprocessing"
    else:
      app = k[0]
    df_stylers.append(v.style.format(formatter={("score"): "{:.1f}", ("text"): "{:.70}"}).set_table_attributes("style='display:inline'").set_caption(app+" with "+k[1]))

  app = df_stylers[0]._repr_html_()
  for i,df_styler in enumerate(df_stylers[1:]):
    if i%2==1:
      app += "<br>" + "-"*230 + "\n"
    app += df_styler._repr_html_()
  display_html(app, raw=True)

# %% [markdown]
# ## Custom Dataset

# %% [markdown]
# ### Data

# %% [markdown]
# > Here we define an illustrative dataframe on which to perform queries

# %%
df = pd.DataFrame({
  'docno':
    ['98', '81', '63', '59', '53', '65', '75', '45'],
    'title':
    ["Bank of Italy",
     "List of italian banks", 
     "Zoology class",
     "History of banking",
     "Title",
     "History of banking",
     "Spam document",
     "History of banking"
    ],
  'text':
    ["The Bank of Italy is the central bank of Italy and part of the European System of Central Banks.",
     "List of italian banks", 
     "History of animals that lived near banks of rivers",
     "Many of histories position the development of a banking system to medieval and Renaissance Italy",
     "History of banking",
     "History of banking: the development of the banking system...",
     "Of of of of of of of of of of of of of of of of apple",
     "spam apple of spam of spam bank spam spam history spam Sony spam spam soccer spam cinema spam spam sales spam buy spam spam TV spam offer spam job work spam Pokémon spam"
    ]
  })

# %%
df
# Out:
#   docno                  title  \
# 0    98          Bank of Italy
# 1    81  List of italian banks
# 2    63          Zoology class
# 3    59     History of banking
# 4    53                  Title
# 5    65     History of banking
# 6    75          Spam document
# 7    45     History of banking
#
#                                                 text
# 0  The Bank of Italy is the central bank of Italy...
# 1                              List of italian banks
# 2  History of animals that lived near banks of ri...
# 3  Many of histories position the development of ...
# 4                                 History of banking
# 5  History of banking: the development of the ban...
# 6  Of of of of of of of of of of of of of of of o...
# 7  spam apple of spam of spam bank spam spam hist...

# %% [markdown]
# ### Indexing

# %% [markdown]
# > To create the index used to perform the queries, we must follow these steps:
# 1. Initialize a **DFIndexer** object, specifying in which folder to put the index
# >> We also specify that we want to *overwrite* the index, if found.
# 2. Set a **preprocessing** configuration.
# 3. Pass the *text* and *docno* **fields** to the indexer
#
# ---
#
# > We create a **function** that takes as argument a *preprocessing_configuration* string, as we want to **repeat** the index creation for various configurations, and returns the computed index. The *field* to be indexed is also an input variable (it will become clear later why).

# %%
def create_index(preprocessing_configuration, field):
  pd_indexer = pt.DFIndexer("./Inverted_Index", overwrite=True)
  
  pd_indexer.setProperty("termpipelines", preprocessing_configuration)
  
  indexref = pd_indexer.index(df[field], df["docno"])

  return indexref

# %% [markdown]
# ###Querying

# %% [markdown]
# > After the index creation, we'll need to specify a **weighting model** (a.k.a. **scoring function**) to compute the score of a document given a query.
#
# > As before, here we define a function that takes as input the previously initialized index and the name of the weighting model and returns the **retrieval model**.

# %%
def create_retrieval_model(indexref, scoring_function):
  return pt.BatchRetrieve(indexref, wmodel = scoring_function)

# %% [markdown]
# > **The retrieval model will take as input a query and return its result**.

# %% [markdown]
# ### First Example

# %% [markdown]
# > First of all, we need to call the functions that we have just defined and create the index and the retrieval model
#
# ---
#
# > To begin with, let's not use any **pre-processing** for the **index**

# %%
indexref = create_index(preprocessing_configuration = "", field = "text")
# Out:
# <ipython-input-14-d00ae2495210>:6: DeprecationWarning: Setting of termpipelines property directly is deprecated
#   indexref = pd_indexer.index(df[field], df["docno"])

# %% [markdown]
# > For the scoring function, let's use **CoordinateMatch**.
#
#  Just 1 if the query's word is in a document for each words.
#
# > We must also remember to feed the *indexref* to the `create_retrieval_model` function

# %%
terms_presence_nopreproc = create_retrieval_model(indexref, scoring_function = "CoordinateMatch")

# %% [markdown]
# > Now we are ready to perform our **query**. Let's assume we want to find out articles about the *History of banking*

# %%
query = "History of banking"
results = terms_presence_nopreproc.search(query)

# %% [markdown]
# > Let's visualize the results

# %%
results
# Out:
#   qid  docid docno  rank  score               query
# 0   1      4    53     0    3.0  History of banking
# 1   1      5    65     1    3.0  History of banking
# 2   1      2    63     2    2.0  History of banking
# 3   1      3    59     3    2.0  History of banking
# 4   1      7    45     4    2.0  History of banking
# 5   1      0    98     5    1.0  History of banking
# 6   1      1    81     6    1.0  History of banking
# 7   1      6    75     7    1.0  History of banking

# %% [markdown]
# > Since this is not much informative, let's add to each row the text corresponding to the document number (*docno*). We'll use a custom printing function defined earlier.

# %%
display_query_result({("text",):results},df)
#YOUR TURN: Try to alter the Pandas DataFrame to see the effect in the output and try to predict it
# Out:
#    rank  score  \
# 0     0    3.0
# 1     1    3.0
# 2     2    2.0
# 3     3    2.0
# 4     4    2.0
# 5     5    1.0
# 6     6    1.0
# 7     7    1.0
#
#                                                                                                                                                                         text
# 0                                                                                                                                                         History of banking
# 1                                                                                                               History of banking: the development of the banking system...
# 2                                                                                                                         History of animals that lived near banks of rivers
# 3                                                                           Many of histories position the development of a banking system to medieval and Renaissance Italy
# 4  spam apple of spam of spam bank spam spam history spam Sony spam spam soccer spam cinema spam spam sales spam buy spam spam TV spam offer spam job work spam Pokémon spam
# 5                                                                           The Bank of Italy is the central bank of Italy and part of the European System of Central Banks.
# 6                                                                                                                                                      List of italian banks
# 7                                                                                                                      Of of of of of of of of of of of of of of of of apple

# %% [markdown]
# ### More rigorous tests

# %% [markdown]
# > Now that we have understood how to initialise an index, create a retrieval model and make a query, let's try to see what changes depending on the preprocessing used and the scoring function chosen.

# %%
possible_preprocessing = ["", #no preprocessing
                          "Stopwords", #remove stopwords
                          "EnglishSnowballStemmer", #Probably the most famous stemmer in the world
                          "Stopwords, EnglishSnowballStemmer"] #Both previous ones

possible_wmodels = ["CoordinateMatch", #Term presence
                    "Tf"] #Term frequency

#YOUR TURN: Try to change preprocessing and/or scoring function; use PyTerrier documentation for reference.

# %% [markdown]
# > Let us now build a program that tries every possible **combination of preprocessing configuration and scoring function**, and then we can check the difference in the results.
#
# > The query will always be `"History of banking"`.
#
# > A python `dict` will be used to save the results for each combination of preprocessing and scoring function.

# %%
query = "History of banking"
results_dict = {}
for preprocessing_configuration in possible_preprocessing:
  indexref = create_index(preprocessing_configuration, "text")
  for wmodel in possible_wmodels:
    retrieval_model = create_retrieval_model(indexref, wmodel)
    results = retrieval_model.search(query)

    results_dict[(preprocessing_configuration, wmodel)] = format_query_result(results,df,("text",))
# Out:
# <ipython-input-12-d00ae2495210>:6: DeprecationWarning: Setting of termpipelines property directly is deprecated
#   indexref = pd_indexer.index(df[field], df["docno"])

# %% [markdown]
# > Now, using a custom function, we will show all the results in a matrix fashion to highlight the differences between the different configurations.

# %%
display_matrix_results(results_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d6c9_" style='display:inline'>
#   <caption>No preprocessing with CoordinateMatch</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >rank</th>
#       <th class="col_heading level0 col1" >score</th>
#       <th class="col_heading level0 col2" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d6c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d6c9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3d6c9_row0_col1" class="data row0 col1" >3.0</td>
#       <td id="T_3d6c9_row0_col2" class="data row0 col2" >History of banking</td>
#     </tr>
#     <tr>
#       <th id="T_3d6c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d6c9_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_3d6c9_row1_col1" class="data row1 col1" >3.0</td>
#       <td id="T_3d6c9_row1_col2" class="data row1 col2" >History of banking: the development of the banking system...</td>
#     </tr>
#     <tr>
#       <th id="T_3d6c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d6c9_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_3d6c9_row2_col1" class="data row2 col1" >2.0</td>
#       <td id="T_3d6c9_row2_col2" class="data row2 col2" >History of animals that lived near banks of rivers</td>
#     </tr>
#     <tr>
#       <th id="T_3d6c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d6c9_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_3d6c9_row3_col1" class="data row3 col1" >2.0</td>
#       <td id="T_3d6c9_row3_col2" class="data row3 col2" >Many of histories position the development of a banking system to medi</td>
#     </tr>
#     <tr>
#       <th id="T_3d6c9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d6c9_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_3d6c9_row4_col1" class="data row4 col1" >2.0</td>
#       <td id="T_3d6c9_row4_col2" class="data row4 col2" >spam apple of spam of spam bank spam spam history spam Sony spam spam </td>
#     </tr>
#     <tr>
#       <th id="T_3d6c9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d6c9_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_3d6c9_row5_col1" class="data row5 col1" >1.0</td>
#       <td id="T_3d6c9_row5_col2" class="data row5 col2" >The Bank of Italy is the central bank of Italy and part of the Europea</td>
#     </tr>
#     <tr>
#       <th id="T_3d6c9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d6c9_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_3d6c9_row6_col1" class="data row6 col1" >1.0</td>
#       <td id="T_3d6c9_row6_col2" class="data row6 col2" >List of italian banks</td>
#     </tr>
#     <tr>
#       <th id="T_3d6c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d6c9_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_3d6c9_row7_col1" class="data row7 col1" >1.0</td>
#       <td id="T_3d6c9_row7_col2" class="data row7 col2" >Of of of of of of of of of of of of of of of of apple</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2e16e_" style='display:inline'>
#   <caption>No preprocessing with Tf</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >rank</th>
#       <th class="col_heading level0 col1" >score</th>
#       <th class="col_heading level0 col2" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e16e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e16e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2e16e_row0_col1" class="data row0 col1" >16.0</td>
#       <td id="T_2e16e_row0_col2" class="data row0 col2" >Of of of of of of of of of of of of of of of of apple</td>
#     </tr>
#     <tr>
#       <th id="T_2e16e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e16e_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_2e16e_row1_col1" class="data row1 col1" >5.0</td>
#       <td id="T_2e16e_row1_col2" class="data row1 col2" >History of banking: the development of the banking system...</td>
#     </tr>
#     <tr>
#       <th id="T_2e16e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e16e_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_2e16e_row2_col1" class="data row2 col1" >4.0</td>
#       <td id="T_2e16e_row2_col2" class="data row2 col2" >The Bank of Italy is the central bank of Italy and part of the Europea</td>
#     </tr>
#     <tr>
#       <th id="T_2e16e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e16e_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_2e16e_row3_col1" class="data row3 col1" >3.0</td>
#       <td id="T_2e16e_row3_col2" class="data row3 col2" >History of animals that lived near banks of rivers</td>
#     </tr>
#     <tr>
#       <th id="T_2e16e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e16e_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_2e16e_row4_col1" class="data row4 col1" >3.0</td>
#       <td id="T_2e16e_row4_col2" class="data row4 col2" >Many of histories position the development of a banking system to medi</td>
#     </tr>
#     <tr>
#       <th id="T_2e16e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2e16e_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_2e16e_row5_col1" class="data row5 col1" >3.0</td>
#       <td id="T_2e16e_row5_col2" class="data row5 col2" >History of banking</td>
#     </tr>
#     <tr>
#       <th id="T_2e16e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2e16e_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_2e16e_row6_col1" class="data row6 col1" >3.0</td>
#       <td id="T_2e16e_row6_col2" class="data row6 col2" >spam apple of spam of spam bank spam spam history spam Sony spam spam </td>
#     </tr>
#     <tr>
#       <th id="T_2e16e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2e16e_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_2e16e_row7_col1" class="data row7 col1" >1.0</td>
#       <td id="T_2e16e_row7_col2" class="data row7 col2" >List of italian banks</td>
#     </tr>
#   </tbody>
# </table>
# <br>--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# <style type="text/css">
# </style>
# <table id="T_63485_" style='display:inline'>
#   <caption>Stopwords with CoordinateMatch</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >rank</th>
#       <th class="col_heading level0 col1" >score</th>
#       <th class="col_heading level0 col2" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63485_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63485_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_63485_row0_col1" class="data row0 col1" >2.0</td>
#       <td id="T_63485_row0_col2" class="data row0 col2" >History of banking</td>
#     </tr>
#     <tr>
#       <th id="T_63485_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63485_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_63485_row1_col1" class="data row1 col1" >2.0</td>
#       <td id="T_63485_row1_col2" class="data row1 col2" >History of banking: the development of the banking system...</td>
#     </tr>
#     <tr>
#       <th id="T_63485_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63485_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_63485_row2_col1" class="data row2 col1" >1.0</td>
#       <td id="T_63485_row2_col2" class="data row2 col2" >History of animals that lived near banks of rivers</td>
#     </tr>
#     <tr>
#       <th id="T_63485_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63485_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_63

# %% [markdown]
# ### Indexing different fields

# %% [markdown]
# > Using the functions created earlier, we build the index and the resulting retrieval model for the *text* and *title* fields

# %%
text_indexref = create_index("Stopwords, EnglishSnowballStemmer","text")
text_retr_model = create_retrieval_model(text_indexref, "Tf")

title_indexref = create_index("Stopwords, EnglishSnowballStemmer","title")
title_retr_model = create_retrieval_model(title_indexref, "CoordinateMatch")
# Out:
# <ipython-input-12-d00ae2495210>:6: DeprecationWarning: Setting of termpipelines property directly is deprecated
#   indexref = pd_indexer.index(df[field], df["docno"])

# %% [markdown]
# > Now, we can get the results for the same query (*History of banking*) on **different** fields

# %%
query = "History of Banking"

results_text = format_query_result(text_retr_model.search(query),df,("docid","title","text"))
results_title = format_query_result(title_retr_model.search(query),df,("docid","title","text"))

# %%
results_text
# Out:
#    rank  score  docid                  title  \
# 0     0    3.0      0          Bank of Italy
# 1     1    3.0      5     History of banking
# 2     2    2.0      2          Zoology class
# 3     3    2.0      3     History of banking
# 4     4    2.0      4                  Title
# 5     5    2.0      7     History of banking
# 6     6    1.0      1  List of italian banks
#
#                                                 text
# 0  The Bank of Italy is the central bank of Italy...
# 1  History of banking: the development of the ban...
# 2  History of animals that lived near banks of ri...
# 3  Many of histories position the development of ...
# 4                                 History of banking
# 5  spam apple of spam of spam bank spam spam hist...
# 6                              List of italian banks

# %%
results_title
# Out:
#    rank  score  docid                  title  \
# 0     0    2.0      3     History of banking
# 1     1    2.0      5     History of banking
# 2     2    2.0      7     History of banking
# 3     3    1.0      0          Bank of Italy
# 4     4    1.0      1  List of italian banks
#
#                                                 text
# 0  Many of histories position the development of ...
# 1  History of banking: the development of the ban...
# 2  spam apple of spam of spam bank spam spam hist...
# 3  The Bank of Italy is the central bank of Italy...
# 4                              List of italian banks

# %% [markdown]
# ## Indexing file

# %% [markdown]
# > We can also try to index data not within PyTerrier but personal txt files.
#
# > As an example, we will stream the collection of tweets "Democrat vs. Republican Tweets" obtained from Kaggle. It is formatted as "[docno] \t [text] \n". We have stored this data on the web for everyone to access.
#
# > The data is in our shared Drive folder, in the data subfolder. To upload the file to this machine, we need to use the gdown command. We will see this command in more detail in the next sessions.

# %%
# !gdown 12z4xEGPcenFhQm5BA4dFJkE8EIVdAssn
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12z4xEGPcenFhQm5BA4dFJkE8EIVdAssn
# To: /content/tweets.txt
# 100% 12.4M/12.4M [00:00<00:00, 141MB/s]

# %% [markdown]
# > The `tweet_doc_iter` function will download the data from the specified url or file and return a python iterable in the form of a dict.

# %%
df = []
with open("tweets.txt","r") as f:
  for i, line in enumerate(f):
    if i % 1000 == 0:
        print(f'processing document {i}')
    record = line.strip().split('\t')
    if len(record) < 2:
      print(record)
      continue
    docno, text = record[0], record[1] 
    df.append({'docno': docno, 'text': text})
df = pd.DataFrame(df).set_index("docno",drop=False) #drop=False to keep the "docno" column
# Out:
# processing document 0
# processing document 1000
# processing document 2000
# processing document 3000
# processing document 4000
# processing document 5000
# processing document 6000
# processing document 7000
# processing document 8000
# processing document 9000
# processing document 10000
# processing document 11000
# processing document 12000
# processing document 13000
# processing document 14000
# processing document 15000
# processing document 16000
# processing document 17000
# processing document 18000
# processing document 19000
# processing document 20000
# processing document 21000
# processing document 22000
# processing document 23000
# processing document 24000
# processing document 25000
# processing document 26000
# processing document 27000
# processing document 28000
# processing document 29000
# processing document 30000
# processing document 31000
# processing document 32000
# processing document 33000
# processing document 34000
# processing document 35000
# processing document 36000
# processing document 37000
# processing document 38000
# processing document 39000
# processing document 40000
# processing document 41000
# processing document 42000
# processing document 43000
# processing document 44000
# processing document 45000
# processing document 46000
# processing document 47000
# processing document 48000
# processing document 49000
# processing document 50000
# processing document 51000
# processing document 52000
# processing document 53000
# processing document 54000
# processing document 55000
# processing document 56000
# processing document 57000
# processing document 58000
# processing document 59000
# processing document 60000
# processing document 61000
# processing document 62000
# processing document 63000
# processing document 64000
# processing document 65000
# processing document 66000
# processing document 67000
# processing document 68000
# processing document 69000
# processing document 70000
# processing document 71000
# processing document 72000
# processing document 73000
# processing document 74000
# processing document 75000
# processing document 76000
# processing document 77000
# processing document 78000
# processing document 79000
# processing document 80000
# processing document 81000
# processing document 82000
# processing document 83000
# processing document 84000
# processing document 85000
# processing document 86000

# %%
def tweet_doc_iter_from_file(df):
  for row in df.to_dict("records"):
    yield row

# %%
folder_pos = "./iter_index"

# !rm -r $folder_pos #remove index if already created
# Out:
# rm: cannot remove './iter_index': No such file or directory

# %%
indexer = pt.IterDictIndexer(folder_pos, blocks=True)

doc_iter = tweet_doc_iter_from_file(df)
index3 = indexer.index(doc_iter, meta=['docno', 'text'])
# Out:
# <ipython-input-35-5d7e90eead84>:4: DeprecationWarning: specifying meta and meta_lengths in IterDictIndexer.index() is deprecated, use constructor instead
#   index3 = indexer.index(doc_iter, meta=['docno', 'text'])
# 09:11:57.110 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (9132) - further warnings are suppressed
# 09:12:20.219 [ForkJoinPool-1-worker-3] WARN org.terrier.structures.indexing.Indexer - Indexed 2 empty documents

# %% [markdown]
# > As we can see, the `IterDictIndexer` object can index any iterable type

# %%
index_factory = pt.IndexFactory.of(index3)
print(index_factory.getCollectionStatistics().toString())
# Out:
# Number of documents: 86460
# Number of terms: 113652
# Number of postings: 1043269
# Number of fields: 1
# Number of tokens: 1064228
# Field names: [text]
# Positions:   true

# %%
tf = pt.BatchRetrieve(index3, wmodel="Tf", metadata=["docno", "text"])

# Just tell the model to retrive the top ten documents.
retrieval_model = tf % 10

# %%
retrieval_model.search("bitcoin")
# Out:
#   qid  docid  docno                                               text  rank  \
# 0   1  33335  33335  Just like stock trades or financial assets, me...     0
# 1   1  33339  33339  The buying &amp; selling of #bitcoins &amp; ot...     1
# 2   1  50228  50228  We are discussing the challenges and opportuni...     2
# 3   1  70120  70120  RT @FortuneMagazine: Tax bill calls for bitcoi...     3
# 4   1  70121  70121  RT @SiliconANGLE: New law would introduce capi...     4
# 5   1  74245  74245  RT @RepLoudermilk: We are discussing the chall...     5
# 6   1  75811  75811  RT @listendestro: @realDonaldTrump Bitcoin rules.     6
# 7   1  84786  84786  RT @HouseScience: WATCH LIVE: Beyond #Bitcoin:...     7
#
#    score    query
# 0    1.0  bitcoin
# 1    1.0  bitcoin
# 2    1.0  bitcoin
# 3    1.0  bitcoin
# 4    1.0  bitcoin
# 5    1.0  bitcoin
# 6    1.0  bitcoin
# 7    1.0  bitcoin

# %%
retrieval_model.search("money laundering")
# Out:
#   qid  docid  docno                                               text  rank  \
# 0   1  29094  29094  RT @RepTedDeutch: If youre a lobbyist who neve...     0
# 1   1  29098  29098  If youre a lobbyist who never gave us money, I...     1
# 2   1  29247  29247  #Backpage.com CEO Carl Ferrer has pled guilty ...     2
# 3   1  36277  36277  RT @OTLonESPN:  For the leagues to expect any ...     3
# 4   1  39028  39028  8 yrs ago #CitizensUnited opened the floodgate...     4
# 5   1  39720  39720  The Mueller files and other documents suggest ...     5
# 6   1  42835  42835  .@PPAdvocatesINKY, you know full well that mon...     6
# 7   1  46846  46846  Tonight, the House will pass the End Banking f...     7
# 8   1  56161  56161  #PrisonReform is a money and a moral issueIt's...     8
# 9   1  59697  59697  RT @WaysandMeansGOP:  Because we are not talki...     9
#
#    score             query
# 0    2.0  money laundering
# 1    2.0  money laundering
# 2    2.0  money laundering
# 3    2.0  money laundering
# 4    2.0  money laundering
# 5    2.0  money laundering
# 6    2.0  money laundering
# 7    2.0  money laundering
# 8    2.0  money laundering
# 9    2.0  money laundering

# %%
retrieval_model.search("Clinton")
# Out:
#   qid  docid  docno                                               text  rank  \
# 0   1  17029  17029  Russian Spies met w/ Trump Campaign. To discus...     0
# 1   1  86442  86442  We need answers now. We must investigate Clint...     1
# 2   1   5416   5416  RT @DeanObeidallah: I agree 100% with Rudy Giu...     2
# 3   1   9569   9569  RT @JohnBrennan: I served 6 Presidents, 3 Rs &...     3
# 4   1  19038  19038  RT @InvestigateRU: .@RepSarbanes: Trump campai...     4
# 5   1  25364  25364  RT @RepAdamSchiff: Russian social media campai...     5
# 6   1  27303  27303  RT @KellyannePolls: Astonished by the all-out ...     6
# 7   1  28372  28372  Background checks save lives. 24 years ago, Pr...     7
# 8   1  28818  28818  Virtually every Clinton-related matter that Pr...     8
# 9   1  29586  29586  I added a video to a @YouTube playlist http://...     9
#
#    score    query
# 0    2.0  Clinton
# 1    2.0  Clinton
# 2    1.0  Clinton
# 3    1.0  Clinton
# 4    1.0  Clinton
# 5    1.0  Clinton
# 6    1.0  Clinton
# 7    1.0  Clinton
# 8    1.0  Clinton
# 9    1.0  Clinton

# %% [markdown]
# ## PyTerrier Datasets

# %% [markdown]
# > The datasets module allows easy access to existing standard test collections. In particular, each defined dataset can download and provide easy access to:
# * files containing the documents of the corpus,
# * topics (**queries**), as a dataframe, ready for retrieval,
# * relevance assessments (aka, labels or qrels), as a dataframe, ready for evaluation: the **ground truth**.

# %%
terrier_datasets = pt.datasets.list_datasets()

# %% [markdown]
# > Let's have a brief look at the list of datasets provided by the PyTerrier library

# %%
terrier_datasets
# Out:
#                          dataset  \
# 0                          50pct
# 1                        antique
# 2                        vaswani
# 3               msmarco_document
# 4             msmarcov2_document
# ..                           ...
# 641                     irds:hc4
# 654                 irds:neuclir
# 655               irds:neuclir/1
# 662      trec-deep-learning-docs
# 663  trec-deep-learning-passages
#
#                                                 topics topics_lang  \
# 0                               [training, validation]          en
# 1                                        [train, test]          en
# 2                                                 True          en
# 3      [train, dev, test, test-2020, leaderboard-2020]          en
# 4       [train, dev1, dev2, valid1, valid2, trec_2021]          en
# ..                                                 ...         ...
# 641                                               None        None
# 654                                               None        None
# 655                                               None        None
# 662    [train, dev, test, test-2020, leaderboard-2020]          en
# 663  [train, dev, dev.small, eval, eval.small, test...          en
#
#                                              qrels corpus corpus_lang  \
# 0                           [training, validation]   None        None
# 1                                    [train, test]   True          en
# 2                                             True   True          en
# 3                    [train, dev, test, test-2020]   True          en
# 4              [train, dev1, dev2, valid1, valid2]   None        None
# ..                                             ...    ...         ...
# 641                                           None   None        None
# 654                                           None   None        None
# 655                                           None   None        None
# 662                  [train, dev, test, test-2020]   True          en
# 663  [train, dev, test-2019, test-2020, dev.small]   True          en
#
#           index                                           info_url
# 0    [ex2, ex3]                                               None
# 1          None  https://ciir.cs.umass.edu/downloads/Antique/re...
# 2          True  http://ir.dcs.gla.ac.uk/resources/test_collect...
# 3          True               https://microsoft.github.io/msmarco/
# 4          True  https://microsoft.github.io/msmarco/TREC-Deep-...
# ..          ...                                                ...
# 641        None                   https://ir-datasets.com/hc4.html
# 654        None               https://ir-datasets.com/neuclir.html
# 655        None     https://ir-datasets.com/neuclir.html#neuclir/1
# 662        True               https://microsoft.github.io/msmarco/
# 663        True  https://microsoft.github.io/MSMARCO-Passage-Ra...
#
# [420 rows x 8 columns]

# %% [markdown]
# ### Indexing

# %% [markdown]
# > The dataset we will use is the one called Covid, which is part of the TREC (Text REtrieval Conference) collection. This is a collection of biomedical literature articles of COVID-related topics.
# > Each document contains title, abstract, doi and date.

# %% [markdown]
# > After defining the dataset name, we download the dataset using the command `pt.get_dataset`

# %%
dataset_name = 'irds:cord19/trec-covid'

dataset = pt.get_dataset(dataset_name) #download dataset

# %% [markdown]
# > First we define the folder where to put the index.
#
# > We also remove the folder in case it has already been created. This command may be commented if we want to keep an already built index.

# %%
folder_pos = './irds:cord19/trec-covid/'

# !rm -r $folder_pos #remove index if already created
# Out:
# rm: cannot remove './irds:cord19/trec-covid/': No such file or directory

# %% [markdown]
# > We create the indexer using the `IterDictIndexer` method. We need to specify the folder path. We also specify `meta_reverse = []`, that defaults to *docno*; this represents what metadata should we be able to resolve back to a *docid*. If there are two documents with the same docno (as we know they are in this case), not specifying it will lead to an error in index creation.
#
# > The indexer is now ready to index the dataset, that is passed to it using the `get_corput_iter` method. We specify also the `fields` to index, *abstract* and *title*, and the `meta` data we want to retrieve from each query. We have added *title* and *abstract* just to have a more informative query result, but normally you only need the `docno`.

# %%
indexer = pt.IterDictIndexer(folder_pos,  meta_reverse = [], blocks = True)
index1 = indexer.index(dataset.get_corpus_iter(), fields=('abstract','title'), meta=('docno','title','abstract'))
# Out:
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 82.9%| 223M/269M [00:07<00:01, 30.2MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 84.4%| 227M/269M [00:07<00:01, 30.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 85.9%| 231M/269M [00:07<00:01, 30.3MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 87.4%| 235M/269M [00:07<00:01, 30.4MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 89.0%| 239M/269M [00:07<00:00, 30.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 90.5%| 244M/269M [00:07<00:00, 30.5MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 92.0%| 248M/269M [00:08<00:00, 30.6MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 93.5%| 252M/269M [00:08<00:00, 30.7MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 95.0%| 256M/269M [00:08<00:00, 30.8MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 96.6%| 260M/269M [00:08<00:00, 30.9MB/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: 98.1%| 264M/269M [00:08<00:00, 30.9MB/s]
#
# [INFO] [finished] https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: [00:08] [269MB] [31.0MB/s]
# docs_iter:   0%|                                    | 0/192509 [00:09<?, ?doc/s]
# https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-07-16/metadata.csv: [00:08] [269MB] [30.9MB/s]
# docs_iter: 100%|█████████████████████| 192509/192509 [00:25<00:00, 7561.11doc/s]
# [INFO] [finished] docs_iter: [00:25] [192509doc] [7560.65doc/s]
# [INFO] [finished] building docstore [25.48s]
# cord19/trec-covid documents:   0%|          | 0/192509 [00:00<?, ?it/s]
# <ipython-input-52-882ae1896157>:2: DeprecationWarning: specifying meta and meta_lengths in IterDictIndexer.index() is deprecated, use constructor instead
#   index1 = indexer.index(dataset.get_corpus_iter(), fields=('abstract','title'), meta=('docno','title','abstract'))
# 09:22:48.754 [ForkJoinPool-2-worker-3] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (8is9x9sc) - further warnings are suppressed
# 09:25:09.159 [ForkJoinPool-2-worker-3] WARN org.terrier.structures.indexing.Indexer - Indexed 60 empty documents

# %% [markdown]
# > We use pyterrier's `IndexFactory` method to obtain some statistics on the newly created index, such as the number of documents and terms indexed.

# %%
index_factory = pt.IndexFactory.of(index1)
print(index_factory.getCollectionStatistics().toString())
# Out:
# Number of documents: 192509
# Number of terms: 158515
# Number of postings: 12290426
# Number of fields: 2
# Number of tokens: 19603234
# Field names: [abstract, title]
# Positions:   true

# %% [markdown]
# ### Querying

# %% [markdown]
# > The query will be *protein variants*, the scoring function will be **tf-idf**

# %%
query = "protein variants"

# %%
tf_idf_results = pt.BatchRetrieve(index1, wmodel = "TF_IDF", metadata = ["docno", "title", "abstract"]).search(query, )

# %%
tf_idf_results
# Out:
#     qid   docid     docno                                              title  \
# 0     1   97334  4nfxdppt  Structural variations in human ACE2 may influe...
# 1     1  153468  m0w0fl2u  Structural variations in human ACE2 may influe...
# 2     1   74549  m0xvqplq  D614G Spike Variant Does Not Alter IgG, IgM, o...
# 3     1  167441  eb7g9p1x  Localization of extensive deletions in the str...
# 4     1  177319  5pmp33d0  New variants of porcine epidemic diarrhea viru...
# ..   ..     ...       ...                                                ...
# 995   1  142159  ynown7ra  Outbreak-Related Porcine Epidemic Diarrhea Vir...
# 996   1  167386  y9e5fz3j  Complete Genome Sequence of the Porcine Epidem...
# 997   1   40784  d14vro73  Interferon lambda 4 genotypes and resistance-a...
# 998   1     602  cjzecgrb  Geometry and Adhesion of Extracellular Domains...
# 999   1   62182  ndhwaeci  Emerging role of microRNA 628-5p as a novel bi...
#
#                                               abstract  rank     score  \
# 0    The recent pandemic of COVID-19, caused by SAR...     0  9.645741
# 1    The recent pandemic of COVID19, caused by SARS...     1  9.645741
# 2    Emergence of a new variant of spike protein (D...     2  9.616081
# 3    Abstract The intracellular RNA of two neurotro...     3  9.605184
# 4    Four types of porcine epidemic diarrhea virus ...     4  9.534034
# ..                                                 ...   ...       ...
# 995  In late 2013, outbreaks of porcine epidemic di...   995  4.551310
# 996  Porcine epidemic diarrhea virus (PEDV) is a ca...   996  4.551310
# 997  UNLABELLED Single-nucleotide polymorphisms (SN...   997  4.550411
# 998  [Image: see text] Forcedistance measurements h...   998  4.538761
# 999  MicroRNAs are a family of small, single-strand...   999  4.538761
#
#                 query
# 0    protein variants
# 1    protein variants
# 2    protein variants
# 3    protein variants
# 4    protein variants
# ..                ...
# 995  protein variants
# 996  protein variants
# 997  protein variants
# 998  protein variants
# 999  protein variants
#
# [1000 rows x 8 columns]

# %% [markdown]
# > Let's see an example of a results

# %%
tf_idf_results.iloc[2]["title"]
# Out:
# 'D614G Spike Variant Does Not Alter IgG, IgM, or IgA Spike Seroassay Performance'

# %%
tf_idf_results.iloc[2]["abstract"]
# Out:
# 'Emergence of a new variant of spike protein (D614G) with increased infectivity and transmissibility has prompted many to analyze the potential role of this variant in the SARS-CoV-2 pandemic. When a new variant emerges, there is a concern regarding whether an individual exposed to one variant of a virus will have cross-reactive immune memory to the second variant. Accordingly, we analyzed the serologic reactivity of D614 (original) and G614 variant spike proteins. We found that antibodies from a high-incid'

# %% [markdown]
# ### Running Experiments
# > PyTerrier aims to make it easy to conduct an information retrieval **experiment**, namely, to run a transformer **pipeline** over a set of queries, and evaluating the outcome using standard information retrieval evaluation metrics based on known relevant documents (obtained from a set relevance assessments, also known as qrels).
#
# > The main way to achieve this is using `pt.Experiment()`.

# %% [markdown]
# > Let's first define some scoring functions.
#
# > After, we specify that we want to use only the first 10 results.

# %%
CoordinateMatch = pt.BatchRetrieve(index1, wmodel="CoordinateMatch")
TF = pt.BatchRetrieve(index1, wmodel="Tf")
TF_IDF = pt.BatchRetrieve(index1, wmodel="TF_IDF")
LemurTF_IDF = pt.BatchRetrieve(index1, wmodel="LemurTF_IDF")
BM25 = pt.BatchRetrieve(index1, wmodel="BM25")
PL2 = pt.BatchRetrieve(index1, wmodel="PL2")
BM25F = pt.BatchRetrieve(index1, wmodel="BM25F")
PL2F = pt.BatchRetrieve(index1, wmodel="PL2F")

CoordinateMatch_at_10 = CoordinateMatch % 10
TF_at_10 = TF % 10
TF_IDF_at_10 = TF_IDF % 10
LemurTF_IDF_at_10 = LemurTF_IDF % 10
BM25_at_10 = BM25 % 10
PL2_at_10 = PL2 % 10
BM25F_at_10 = BM25F % 10
PL2F_at_10 = PL2F % 10

# %% [markdown]
# > Complete list:
# http://www.terrier.org/docs/current/javadoc///org/terrier/matching/models/package-summary.html

# %% [markdown]
# > Let's also try some **query expansion** techniques.
# It is the process of reformulating a given query to improve retrieval performance in information retrieval operations
# *   Finding synonyms of words, and searching for the synonyms as well,
# *   Finding semantically related words (e.g. antonyms, meronyms, hyponyms, hypernyms),
# *   Finding all the various morphological forms of words by stemming each word in the search query,
# *   Fixing spelling errors and automatically searching for the corrected form or suggesting it in the results,
# *   Re-weighting the terms in the original query,
# *   etc...

# %%
sdm = pt.rewrite.SDM()
bo1 = pt.rewrite.Bo1QueryExpansion(index1)
pipeline_1_at_10 = sdm >> TF_IDF % 10
pipeline_2_at_10 = TF_IDF >> bo1 >> TF_IDF % 10

# %% [markdown]
# > Extraction of the ground truth as a set of couples <query, relevant_results>.

# %%
topics = dataset.get_topics("title")
qrels = dataset.get_qrels()
# Out:
# [INFO] [starting] https://ir.nist.gov/covidSubmit/data/topics-rnd5.xml
# [INFO] [finished] https://ir.nist.gov/covidSubmit/data/topics-rnd5.xml: [00:00] [18.7kB] [6.53MB/s]
# [INFO] [starting] https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt
# [INFO] [finished] https://ir.nist.gov/covidSubmit/data/qrels-covid_d5_j0.5-5.txt: [00:00] [1.14MB] [6.87MB/s]

# %% [markdown]
# Let's see what `topics` and `qrels` look like:

# %%
topics
# Out:
#    qid                                          query
# 0    1                             coronavirus origin
# 1    2        coronavirus response to weather changes
# 2    3                           coronavirus immunity
# 3    4         how do people die from the coronavirus
# 4    5                      animal models of covid 19
# 5    6                 coronavirus test rapid testing
# 6    7              serological tests for coronavirus
# 7    8                    coronavirus under reporting
# 8    9                          coronavirus in canada
# 9   10           coronavirus social distancing impact
# 10  11                 coronavirus hospital rationing
# 11  12                         coronavirus quarantine
# 12  13                    how does coronavirus spread
# 13  14                    coronavirus super spreaders
# 14  15                       coronavirus outside body
# 15  16  how long does coronavirus survive on surfaces
# 16  17                    coronavirus clinical trials
# 17  18                      masks prevent coronavirus
# 18  19       what alcohol sanitizer kills coronavirus
# 19  20                 coronavirus and ace inhibitors
# 20  21                          coronavirus mortality
# 21  22                      coronavirus heart impacts
# 22  23                       coronavirus hypertension
# 23  24                           coronavirus diabetes
# 24  25                         coronavirus biomarkers
# 25  26                     coronavirus early symptoms
# 26  27                       coronavirus asymptomatic
# 27  28                 coronavirus hydroxychloroquine
# 28  29                   coronavirus drug repurposing
# 29  30                         coronavirus remdesivir
# 30  31         difference between coronavirus and flu
# 31  32                           coronavirus subtypes
# 32  33                 coronavirus vaccine candidates
# 33  34                           coronavirus recovery
# 34  35                    coronavirus public datasets
# 35  36                     sars cov 2 spike structure
# 36  37               sars cov 2 phylogenetic analysis
# 37  38                    covid inflammatory response
# 38  39                        covid 19 cytokine storm
# 39  40                          coronavirus mutations
# 40  41                  covid 19 in african americans
# 41  42                         vitamin d and covid 19
# 42  43                       violence during pandemic
# 43  44    impact of masks on coronavirus transmission
# 44  45               coronavirus mental health impact
# 45  46                      dexamethasone coronavirus
# 46  47                  covid 19 outcomes in children
# 47  48                   school reopening coronavirus
# 48  49               post infection covid 19 immunity
# 49  50                       mrna vaccine coronavirus

# %% [markdown]
# `label` represents the relevance score. It can be binary (0 = not relevant, 1 = relevant) or graded (higher the label, higher the relevance).

# %%
qrels
# Out:
#       qid     docno  label iteration
# 0       1  005b2j4b      2       4.5
# 1       1  00fmeepz      1         4
# 2       1  010vptx3      2       0.5
# 3       1  0194oljo      1       2.5
# 4       1  021q9884      1         4
# ...    ..       ...    ...       ...
# 69313  50  zvop8bxh      2         5
# 69314  50  zwf26o63      1         5
# 69315  50  zwsvlnwe      0         5
# 69316  50  zxr01yln      1         5
# 69317  50  zz8wvos9      1         5
#
# [69318 rows x 4 columns]

# %% [markdown]
# > Let's run the experiment.

# %%
res_exp_covid = pt.Experiment(
    [CoordinateMatch_at_10, TF_at_10, TF_IDF_at_10, LemurTF_IDF_at_10, BM25_at_10, PL2_at_10, BM25F_at_10, PL2F_at_10, pipeline_1_at_10, pipeline_2_at_10],
    topics,
    qrels,
    eval_metrics=["P_1", "P_3", "ndcg_cut_3", "P_5", "ndcg_cut_5", "P_10", "ndcg_cut_10", "num_q"],
    #round={"P_1":2, "P_3":2, "P_5":2, "P_10":2, "ndcg_cut_3":2, "ndcg_cut_5":2, "ndcg_cut_10":2, "num_q":0},
    names=["CoordinateMatch_at_10", "TF_at_10", "TF_IDF_at_10", "LemurTF_IDF_at_10", "BM25_at_10", "PL2_at_10", "BM25F_at_10", "PL2F_at_10", "pipeline_1_at_10", "pipeline_2_at_10"],
    highlight="bold"
)

#YOUR TURN: Try different evaluation metrics

# %%
res_exp_covid
# Out:
# <style type="text/css">
# #T_009c4_row0_col8, #T_009c4_row1_col8, #T_009c4_row2_col8, #T_009c4_row3_col8, #T_009c4_row4_col6, #T_009c4_row4_col8, #T_009c4_row5_col8, #T_009c4_row6_col8, #T_009c4_row7_col8, #T_009c4_row8_col8, #T_009c4_row9_col1, #T_009c4_row9_col2, #T_009c4_row9_col3, #T_009c4_row9_col4, #T_009c4_row9_col5, #T_009c4_row9_col7, #T_009c4_row9_col8 {
#   font-weight: bold;
# }
# </style>
# <table id="T_009c4_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >P_1</th>
#       <th class="col_heading level0 col2" >P_3</th>
#       <th class="col_heading level0 col3" >ndcg_cut_3</th>
#       <th class="col_heading level0 col4" >P_5</th>
#       <th class="col_heading level0 col5" >ndcg_cut_5</th>
#       <th class="col_heading level0 col6" >P_10</th>
#       <th class="col_heading level0 col7" >ndcg_cut_10</th>
#       <th class="col_heading level0 col8" >num_q</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_009c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_009c4_row0_col0" class="data row0 col0" >CoordinateMatch_at_10</td>
#       <td id="T_009c4_row0_col1" class="data row0 col1" >0.280000</td>
#       <td id="T_009c4_row0_col2" class="data row0 col2" >0.260000</td>
#       <td id="T_009c4_row0_col3" class="data row0 col3" >0.213464</td>
#       <td id="T_009c4_row0_col4" class="data row0 col4" >0.272000</td>
#       <td id="T_009c4_row0_col5" class="data row0 col5" >0.223892</td>
#       <td id="T_009c4_row0_col6" class="data row0 col6" >0.284000</td>
#       <td id="T_009c4_row0_col7" class="data row0 col7" >0.231387</td>
#       <td id="T_009c4_row0_col8" class="data row0 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_009c4_row1_col0" class="data row1 col0" >TF_at_10</td>
#       <td id="T_009c4_row1_col1" class="data row1 col1" >0.080000</td>
#       <td id="T_009c4_row1_col2" class="data row1 col2" >0.200000</td>
#       <td id="T_009c4_row1_col3" class="data row1 col3" >0.158994</td>
#       <td id="T_009c4_row1_col4" class="data row1 col4" >0.244000</td>
#       <td id="T_009c4_row1_col5" class="data row1 col5" >0.187297</td>
#       <td id="T_009c4_row1_col6" class="data row1 col6" >0.212000</td>
#       <td id="T_009c4_row1_col7" class="data row1 col7" >0.171953</td>
#       <td id="T_009c4_row1_col8" class="data row1 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_009c4_row2_col0" class="data row2 col0" >TF_IDF_at_10</td>
#       <td id="T_009c4_row2_col1" class="data row2 col1" >0.720000</td>
#       <td id="T_009c4_row2_col2" class="data row2 col2" >0.706667</td>
#       <td id="T_009c4_row2_col3" class="data row2 col3" >0.633464</td>
#       <td id="T_009c4_row2_col4" class="data row2 col4" >0.684000</td>
#       <td id="T_009c4_row2_col5" class="data row2 col5" >0.624185</td>
#       <td id="T_009c4_row2_col6" class="data row2 col6" >0.664000</td>
#       <td id="T_009c4_row2_col7" class="data row2 col7" >0.596951</td>
#       <td id="T_009c4_row2_col8" class="data row2 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_009c4_row3_col0" class="data row3 col0" >LemurTF_IDF_at_10</td>
#       <td id="T_009c4_row3_col1" class="data row3 col1" >0.660000</td>
#       <td id="T_009c4_row3_col2" class="data row3 col2" >0.686667</td>
#       <td id="T_009c4_row3_col3" class="data row3 col3" >0.588268</td>
#       <td id="T_009c4_row3_col4" class="data row3 col4" >0.660000</td>
#       <td id="T_009c4_row3_col5" class="data row3 col5" >0.577657</td>
#       <td id="T_009c4_row3_col6" class="data row3 col6" >0.622000</td>
#       <td id="T_009c4_row3_col7" class="data row3 col7" >0.552401</td>
#       <td id="T_009c4_row3_col8" class="data row3 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_009c4_row4_col0" class="data row4 col0" >BM25_at_10</td>
#       <td id="T_009c4_row4_col1" class="data row4 col1" >0.720000</td>
#       <td id="T_009c4_row4_col2" class="data row4 col2" >0.700000</td>
#       <td id="T_009c4_row4_col3" class="data row4 col3" >0.625810</td>
#       <td id="T_009c4_row4_col4" class="data row4 col4" >0.672000</td>
#       <td id="T_009c4_row4_col5" class="data row4 col5" >0.605385</td>
#       <td id="T_009c4_row4_col6" class="data row4 col6" >0.672000</td>
#       <td id="T_009c4_row4_col7" class="data row4 col7" >0.598029</td>
#       <td id="T_009c4_row4_col8" class="data row4 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_009c4_row5_col0" class="data row5 col0" >PL2_at_10</td>
#       <td id="T_009c4_row5_col1" class="data row5 col1" >0.760000</td>
#       <td id="T_009c4_row5_col2" class="data row5 col2" >0.673333</td>
#       <td id="T_009c4_row5_col3" class="data row5 col3" >0.597542</td>
#       <td id="T_009c4_row5_col4" class="data row5 col4" >0.636000</td>
#       <td id="T_009c4_row5_col5" class="data row5 col5" >0.577651</td>
#       <td id="T_009c4_row5_col6" class="data row5 col6" >0.620000</td>
#       <td id="T_009c4_row5_col7" class="data row5 col7" >0.560930</td>
#       <td id="T_009c4_row5_col8" class="data row5 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_009c4_row6_col0" class="data row6 col0" >BM25F_at_10</td>
#       <td id="T_009c4_row6_col1" class="data row6 col1" >0.680000</td>
#       <td id="T_009c4_row6_col2" class="data row6 col2" >0.640000</td>
#       <td id="T_009c4_row6_col3" class="data row6 col3" >0.574581</td>
#       <td id="T_009c4_row6_col4" class="data row6 col4" >0.628000</td>
#       <td id="T_009c4_row6_col5" class="data row6 col5" >0.563384</td>
#       <td id="T_009c4_row6_col6" class="data row6 col6" >0.600000</td>
#       <td id="T_009c4_row6_col7" class="data row6 col7" >0.539246</td>
#       <td id="T_009c4_row6_col8" class="data row6 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_009c4_row7_col0" class="data row7 col0" >PL2F_at_10</td>
#       <td id="T_009c4_row7_col1" class="data row7 col1" >0.760000</td>
#       <td id="T_009c4_row7_col2" class="data row7 col2" >0.700000</td>
#       <td id="T_009c4_row7_col3" class="data row7 col3" >0.601621</td>
#       <td id="T_009c4_row7_col4" class="data row7 col4" >0.700000</td>
#       <td id="T_009c4_row7_col5" class="data row7 col5" >0.616347</td>
#       <td id="T_009c4_row7_col6" class="data row7 col6" >0.662000</td>
#       <td id="T_009c4_row7_col7" class="data row7 col7" >0.591875</td>
#       <td id="T_009c4_row7_col8" class="data row7 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_009c4_row8_col0" class="data row8 col0" >pipeline_1_at_10</td>
#       <td id="T_009c4_row8_col1" class="data row8 col1" >0.720000</td>
#       <td id="T_009c4_row8_col2" class="data row8 col2" >0.720000</td>
#       <td id="T_009c4_row8_col3" class="data row8 col3" >0.630000</td>
#       <td id="T_009c4_row8_col4" class="data row8 col4" >0.680000</td>
#       <td id="T_009c4_row8_col5" class="data row8 col5" >0.616705</td>
#       <td id="T_009c4_row8_col6" class="data row8 col6" >0.666000</td>
#       <td id="T_009c4_row8_col7" class="data row8 col7" >0.592973</td>
#       <td id="T_009c4_row8_col8" class="data row8 col8" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_009c4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_009c4_row9_col0" class="data row9 col0" >pipeline_2_at_10</td>
#       <td id="T_009c4_row9_col1" class="data row9 col1" >0.780000</td>
#       <td id="T_009c4_row9_col2" class="data row9 col2" >0.733333</td>
#       <td id="T_009c4_

# %% [markdown]
# ### Let's test another dataset.
#
# > We use a subset of the **wikipedia** dataset

# %% [markdown]
# > We follow the same procedure as above to download the dataset and create the index

# %%
wiki_dataset_name = 'irds:wikir/en1k/test'

wiki_dataset = pt.get_dataset(wiki_dataset_name) #download dataset

#YOUR TURN: Try to use a different PyTerrier dataset (!!!Not every dataset has queries' relevance scores!!!)

# %%
folder_pos = './indices/wikir_en1k'
# !rm -r $folder_pos #remove index if already created
# Out:
# rm: cannot remove './indices/wikir_en1k': No such file or directory

# %%
indexer = pt.IterDictIndexer(folder_pos,  meta_reverse=[], blocks=True)
index2 = indexer.index(wiki_dataset.get_corpus_iter(), fields=['text'])
# Out:
# wikir/en1k/test documents:   0%|          | 0/369721 [00:00<?, ?it/s]
# [INFO] If you have a local copy of https://zenodo.org/record/3565761/files/wikIR1k.zip, you can symlink it here to avoid downloading it again: /root/.ir_datasets/downloads/554299bca984640cb283d6ba55753608
# [INFO] [starting] https://zenodo.org/record/3565761/files/wikIR1k.zip
#
# https://zenodo.org/record/3565761/files/wikIR1k.zip:
B/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 75.8%| 125M/165M [01:02<00:20, 2.00MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 76.4%| 126M/165M [01:02<00:19, 2.00MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 77.0%| 127M/165M [01:02<00:18, 2.02MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 77.7%| 128M/165M [01:03<00:18, 2.03MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 78.3%| 129M/165M [01:03<00:17, 2.04MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 78.9%| 130M/165M [01:03<00:16, 2.06MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 79.6%| 131M/165M [01:03<00:16, 2.07MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 80.2%| 132M/165M [01:03<00:15, 2.08MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 80.8%| 133M/165M [01:03<00:15, 2.09MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 81.5%| 134M/165M [01:03<00:14, 2.11MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 82.1%| 135M/165M [01:03<00:13, 2.12MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 82.7%| 137M/165M [01:04<00:13, 2.13MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 83.4%| 138M/165M [01:04<00:12, 2.14MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 84.0%| 139M/165M [01:04<00:12, 2.15MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 84.7%| 140M/165M [01:04<00:11, 2.17MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 85.3%| 141M/165M [01:04<00:11, 2.18MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 85.9%| 142M/165M [01:04<00:10, 2.19MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 86.6%| 143M/165M [01:05<00:10, 2.20MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 87.2%| 144M/165M [01:05<00:09, 2.20MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 87.8%| 145M/165M [01:05<00:09, 2.20MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 88.5%| 146M/165M [01:05<00:08, 2.21MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 89.1%| 147M/165M [01:06<00:08, 2.23MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 89.7%| 148M/165M [01:06<00:07, 2.24MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 90.4%| 149M/165M [01:06<00:07, 2.25MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 91.0%| 150M/165M [01:06<00:06, 2.26MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 91.6%| 151M/165M [01:06<00:06, 2.27MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 92.3%| 152M/165M [01:06<00:05, 2.28MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 92.9%| 153M/165M [01:06<00:05, 2.29MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 93.6%| 154M/165M [01:07<00:04, 2.30MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 94.2%| 155M/165M [01:07<00:04, 2.31MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 94.8%| 156M/165M [01:07<00:03, 2.32MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 95.5%| 157M/165M [01:07<00:03, 2.34MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 96.1%| 159M/165M [01:07<00:02, 2.35MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 96.7%| 160M/165M [01:07<00:02, 2.36MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 97.4%| 161M/165M [01:07<00:01, 2.36MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 98.0%| 162M/165M [01:08<00:01, 2.38MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 98.6%| 163M/165M [01:08<00:00, 2.38MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 99.3%| 164M/165M [01:08<00:00, 2.40MB/s]
# https://zenodo.org/record/3565761/files/wikIR1k.zip: 99.9%| 165M/165M [01:08<00:00, 2.41MB/s]
# [INFO] [finished] https://zenodo.org/record/3565761/files/wikIR1k.zip: [01:08] [165MB] [2.41MB/s]
#
# https://zenodo.org/record/3565761/files/wikIR1k.zip: [01:08] [165MB] [2.41MB/s]

# %% [markdown]
# > Let's see some statistics on this new index

# %%
index_factory = pt.IndexFactory.of(index2)
print(index_factory.getCollectionStatistics().toString())
# Out:
# Number of documents: 369721
# Number of terms: 674552
# Number of postings: 30552936
# Number of fields: 1
# Number of tokens: 41306796
# Field names: [text]
# Positions:   true

# %% [markdown]
# > We set up the same experiment on the Covid dataset to highlight the differences with the previous case.

# %%
CoordinateMatch = pt.BatchRetrieve(index2, wmodel="CoordinateMatch")
TF = pt.BatchRetrieve(index2, wmodel="Tf")
TF_IDF = pt.BatchRetrieve(index2, wmodel="TF_IDF")
LemurTF_IDF = pt.BatchRetrieve(index2, wmodel="LemurTF_IDF")
BM25 = pt.BatchRetrieve(index2, wmodel="BM25")
PL2 = pt.BatchRetrieve(index2, wmodel="PL2")

CoordinateMatch_at_10 = CoordinateMatch % 10
TF_at_10 = TF % 10
TF_IDF_at_10 = TF_IDF % 10
LemurTF_IDF_at_10 = LemurTF_IDF % 10
BM25_at_10 = BM25 % 10
PL2_at_10 = PL2 % 10

# %%
sdm = pt.rewrite.SDM()
bo1 = pt.rewrite.Bo1QueryExpansion(index2)
pipeline_1_at_10 = sdm >> TF_IDF % 10
pipeline_2_at_10 = TF_IDF >> bo1 >> TF_IDF % 10
pipeline_3_at_10 = sdm >> BM25 % 10
pipeline_4_at_10 = BM25 >> bo1 >> BM25 % 10

# %%
topics = wiki_dataset.get_topics()
qrels = wiki_dataset.get_qrels()

# %% [markdown]
# > Let's run the experiment

# %%
res_exp_wiki_dataset = pt.Experiment(
    [CoordinateMatch_at_10, TF_at_10, TF_IDF_at_10, LemurTF_IDF_at_10, BM25_at_10, PL2_at_10, pipeline_1_at_10, pipeline_2_at_10, pipeline_3_at_10, pipeline_4_at_10],
    topics,
    qrels,
    eval_metrics=["P_1", "P_3", "ndcg_cut_3", "P_5", "ndcg_cut_5", "P_10", "ndcg_cut_10", "num_q"],
    #round={"P_1":2, "P_3":2, "P_5":2, "P_10":2, "ndcg_cut_3":2, "ndcg_cut_5":2, "ndcg_cut_10":2, "num_q":0},
    names=["CoordinateMatch_at_10", "TF_at_10", "TF_IDF_at_10", "LemurTF_IDF_at_10", "BM25_at_10", "PL2_at_10", "pipeline_1_at_10", "pipeline_2_at_10","pipeline_3_at_10", "pipeline_4_at_10"],
    highlight="bold"
)

# %%
res_exp_wiki_dataset
# Out:
# <style type="text/css">
# #T_43a36_row0_col8, #T_43a36_row1_col8, #T_43a36_row2_col1, #T_43a36_row2_col8, #T_43a36_row3_col1, #T_43a36_row3_col5, #T_43a36_row3_col8, #T_43a36_row4_col1, #T_43a36_row4_col3, #T_43a36_row4_col8, #T_43a36_row5_col8, #T_43a36_row6_col1, #T_43a36_row6_col8, #T_43a36_row7_col6, #T_43a36_row7_col8, #T_43a36_row8_col1, #T_43a36_row8_col8, #T_43a36_row9_col2, #T_43a36_row9_col4, #T_43a36_row9_col6, #T_43a36_row9_col7, #T_43a36_row9_col8 {
#   font-weight: bold;
# }
# </style>
# <table id="T_43a36_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >P_1</th>
#       <th class="col_heading level0 col2" >P_3</th>
#       <th class="col_heading level0 col3" >ndcg_cut_3</th>
#       <th class="col_heading level0 col4" >P_5</th>
#       <th class="col_heading level0 col5" >ndcg_cut_5</th>
#       <th class="col_heading level0 col6" >P_10</th>
#       <th class="col_heading level0 col7" >ndcg_cut_10</th>
#       <th class="col_heading level0 col8" >num_q</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43a36_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43a36_row0_col0" class="data row0 col0" >CoordinateMatch_at_10</td>
#       <td id="T_43a36_row0_col1" class="data row0 col1" >0.140000</td>
#       <td id="T_43a36_row0_col2" class="data row0 col2" >0.120000</td>
#       <td id="T_43a36_row0_col3" class="data row0 col3" >0.117148</td>
#       <td id="T_43a36_row0_col4" class="data row0 col4" >0.106000</td>
#       <td id="T_43a36_row0_col5" class="data row0 col5" >0.114467</td>
#       <td id="T_43a36_row0_col6" class="data row0 col6" >0.083000</td>
#       <td id="T_43a36_row0_col7" class="data row0 col7" >0.116916</td>
#       <td id="T_43a36_row0_col8" class="data row0 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43a36_row1_col0" class="data row1 col0" >TF_at_10</td>
#       <td id="T_43a36_row1_col1" class="data row1 col1" >0.260000</td>
#       <td id="T_43a36_row1_col2" class="data row1 col2" >0.206667</td>
#       <td id="T_43a36_row1_col3" class="data row1 col3" >0.240570</td>
#       <td id="T_43a36_row1_col4" class="data row1 col4" >0.164000</td>
#       <td id="T_43a36_row1_col5" class="data row1 col5" >0.220615</td>
#       <td id="T_43a36_row1_col6" class="data row1 col6" >0.133000</td>
#       <td id="T_43a36_row1_col7" class="data row1 col7" >0.210467</td>
#       <td id="T_43a36_row1_col8" class="data row1 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43a36_row2_col0" class="data row2 col0" >TF_IDF_at_10</td>
#       <td id="T_43a36_row2_col1" class="data row2 col1" >0.550000</td>
#       <td id="T_43a36_row2_col2" class="data row2 col2" >0.383333</td>
#       <td id="T_43a36_row2_col3" class="data row2 col3" >0.450609</td>
#       <td id="T_43a36_row2_col4" class="data row2 col4" >0.314000</td>
#       <td id="T_43a36_row2_col5" class="data row2 col5" >0.410183</td>
#       <td id="T_43a36_row2_col6" class="data row2 col6" >0.211000</td>
#       <td id="T_43a36_row2_col7" class="data row2 col7" >0.358951</td>
#       <td id="T_43a36_row2_col8" class="data row2 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43a36_row3_col0" class="data row3 col0" >LemurTF_IDF_at_10</td>
#       <td id="T_43a36_row3_col1" class="data row3 col1" >0.550000</td>
#       <td id="T_43a36_row3_col2" class="data row3 col2" >0.396667</td>
#       <td id="T_43a36_row3_col3" class="data row3 col3" >0.457909</td>
#       <td id="T_43a36_row3_col4" class="data row3 col4" >0.320000</td>
#       <td id="T_43a36_row3_col5" class="data row3 col5" >0.415638</td>
#       <td id="T_43a36_row3_col6" class="data row3 col6" >0.217000</td>
#       <td id="T_43a36_row3_col7" class="data row3 col7" >0.364739</td>
#       <td id="T_43a36_row3_col8" class="data row3 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43a36_row4_col0" class="data row4 col0" >BM25_at_10</td>
#       <td id="T_43a36_row4_col1" class="data row4 col1" >0.550000</td>
#       <td id="T_43a36_row4_col2" class="data row4 col2" >0.393333</td>
#       <td id="T_43a36_row4_col3" class="data row4 col3" >0.458176</td>
#       <td id="T_43a36_row4_col4" class="data row4 col4" >0.318000</td>
#       <td id="T_43a36_row4_col5" class="data row4 col5" >0.413779</td>
#       <td id="T_43a36_row4_col6" class="data row4 col6" >0.212000</td>
#       <td id="T_43a36_row4_col7" class="data row4 col7" >0.360993</td>
#       <td id="T_43a36_row4_col8" class="data row4 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_43a36_row5_col0" class="data row5 col0" >PL2_at_10</td>
#       <td id="T_43a36_row5_col1" class="data row5 col1" >0.530000</td>
#       <td id="T_43a36_row5_col2" class="data row5 col2" >0.380000</td>
#       <td id="T_43a36_row5_col3" class="data row5 col3" >0.444639</td>
#       <td id="T_43a36_row5_col4" class="data row5 col4" >0.308000</td>
#       <td id="T_43a36_row5_col5" class="data row5 col5" >0.405116</td>
#       <td id="T_43a36_row5_col6" class="data row5 col6" >0.211000</td>
#       <td id="T_43a36_row5_col7" class="data row5 col7" >0.356806</td>
#       <td id="T_43a36_row5_col8" class="data row5 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_43a36_row6_col0" class="data row6 col0" >pipeline_1_at_10</td>
#       <td id="T_43a36_row6_col1" class="data row6 col1" >0.550000</td>
#       <td id="T_43a36_row6_col2" class="data row6 col2" >0.376667</td>
#       <td id="T_43a36_row6_col3" class="data row6 col3" >0.444564</td>
#       <td id="T_43a36_row6_col4" class="data row6 col4" >0.314000</td>
#       <td id="T_43a36_row6_col5" class="data row6 col5" >0.408772</td>
#       <td id="T_43a36_row6_col6" class="data row6 col6" >0.207000</td>
#       <td id="T_43a36_row6_col7" class="data row6 col7" >0.354761</td>
#       <td id="T_43a36_row6_col8" class="data row6 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_43a36_row7_col0" class="data row7 col0" >pipeline_2_at_10</td>
#       <td id="T_43a36_row7_col1" class="data row7 col1" >0.480000</td>
#       <td id="T_43a36_row7_col2" class="data row7 col2" >0.396667</td>
#       <td id="T_43a36_row7_col3" class="data row7 col3" >0.444106</td>
#       <td id="T_43a36_row7_col4" class="data row7 col4" >0.332000</td>
#       <td id="T_43a36_row7_col5" class="data row7 col5" >0.410683</td>
#       <td id="T_43a36_row7_col6" class="data row7 col6" >0.229000</td>
#       <td id="T_43a36_row7_col7" class="data row7 col7" >0.367024</td>
#       <td id="T_43a36_row7_col8" class="data row7 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_43a36_row8_col0" class="data row8 col0" >pipeline_3_at_10</td>
#       <td id="T_43a36_row8_col1" class="data row8 col1" >0.550000</td>
#       <td id="T_43a36_row8_col2" class="data row8 col2" >0.390000</td>
#       <td id="T_43a36_row8_col3" class="data row8 col3" >0.456161</td>
#       <td id="T_43a36_row8_col4" class="data row8 col4" >0.316000</td>
#       <td id="T_43a36_row8_col5" class="data row8 col5" >0.412736</td>
#       <td id="T_43a36_row8_col6" class="data row8 col6" >0.211000</td>
#       <td id="T_43a36_row8_col7" class="data row8 col7" >0.360072</td>
#       <td id="T_43a36_row8_col8" class="data row8 col8" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_43a36_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_43a36_row9_col0" class="data row9 col0" >pipeline_4_at_10</td>
#       <td id="T_43a36_row9_col1" class="data row9 col

# %% [markdown]
# > We can see that there is not always one method that prevails over the others, but it often depends on the metrics taken into consideration.
